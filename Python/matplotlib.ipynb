# %% [markdown]
# ## np=ds+math+array(rich library)

# %% [markdown]
# ## matplotlib=ds+math+stats+visualization+graphs

# %% [markdown]
# ## matplotlib(visualization)

# %%
## how to read image

# %%
import matplotlib.pyplot as plt

# %%
from PIL import Image

# %%
ss=Image.open(r"C:\Users\Shivam Kumar yadav\OneDrive\Pictures\Screenshots\Screenshot 2025-08-02 114430.png")
ss
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1920x1080>
